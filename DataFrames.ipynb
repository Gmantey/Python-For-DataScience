# %%
data = {"name": ["Sophia" , "John" , "Jen", "Pat", "Steve"],
       "gender": ["F" , "M", "F", "M", "M"],
       "country": ["Bulgaria", "USA" , "USA" , "England", "Netherlands"],
       "age": [23,24,46,13,66]}
data
# Out:
# {'name': ['Sophia', 'John', 'Jen', 'Pat', 'Steve'],
#  'gender': ['F', 'M', 'F', 'M', 'M'],
#  'country': ['Bulgaria', 'USA', 'USA', 'England', 'Netherlands'],
#  'age': [23, 24, 46, 13, 66]}

# %%
import pandas as pd

# %% [markdown]
# # How to Create a DATAFRAME
# ### Find the Columns, Index

# %%
df = pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['name', 'gender', 'country', 'age'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# > Instead of Using a standard index like 0 to n-1, we can use any of the column as an index
#
# > Below we used the name as the index. (Read more about **set_index()** function in Pandas DOC)

# %%
df.set_index('name',drop = True, inplace = True)

# %%
df
# Out:
#        gender      country  age
# name
# Sophia      F     Bulgaria   23
# John        M          USA   24
# Jen         F          USA   46
# Pat         M      England   13
# Steve       M  Netherlands   66

# %% [markdown]
# # HOW TO READ IN CSV FILES

# %%
data = pd.read_csv('complaints.csv')

# %%
import seaborn as sns

# %%
df.reset_index(inplace = False, drop = False)
# Out:
#      name gender      country  age
# 0  Sophia      F     Bulgaria   23
# 1    John      M          USA   24
# 2     Jen      F          USA   46
# 3     Pat      M      England   13
# 4   Steve      M  Netherlands   66

# %% [markdown]
# #### Seaborn Library Imported

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['tip'].head()
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %% [markdown]
# > Converting it to a data fram

# %%
df[['tip']].head()
# Out:
#     tip
# 0  1.01
# 1  1.66
# 2  3.50
# 3  3.31
# 4  3.61

# %%
df[0:3]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# # .loc --> Label based Indexing

# %%
df.loc[0:10, ['tip' , 'time']]
# Out:
#      tip    time
# 0   1.01  Dinner
# 1   1.66  Dinner
# 2   3.50  Dinner
# 3   3.31  Dinner
# 4   3.61  Dinner
# 5   4.71  Dinner
# 6   2.00  Dinner
# 7   3.12  Dinner
# 8   1.96  Dinner
# 9   3.23  Dinner
# 10  1.71  Dinner

# %% [markdown]
# # .iloc --> Integer based indexing

# %%
df.iloc[0:13 , [3 ,4]].head()
# Out:
#   smoker  day
# 0     No  Sun
# 1     No  Sun
# 2     No  Sun
# 3     No  Sun
# 4     No  Sun

# %% [markdown]
# # Performing Filtering on Rows

# %%
data = pd.read_csv('complaints.csv')

# %% [markdown]
# #### Make a subset using a condition and the then reference it as a data frame

# %%
df = (data['Product'] == "Vehicle loan or lease") 
data[df]
# Out:
#         Date received                Product Sub-product  \
# 4          2019-02-08  Vehicle loan or lease       Lease
# 126        2019-05-31  Vehicle loan or lease        Loan
# 156        2018-10-24  Vehicle loan or lease        Loan
# 193        2019-04-02  Vehicle loan or lease       Lease
# 195        2019-06-05  Vehicle loan or lease        Loan
# ...               ...                    ...         ...
# 1627030    2018-12-07  Vehicle loan or lease        Loan
# 1627173    2018-11-20  Vehicle loan or lease       Lease
# 1627192    2018-12-04  Vehicle loan or lease       Lease
# 1627237    2018-07-24  Vehicle loan or lease        Loan
# 1627259    2018-12-04  Vehicle loan or lease        Loan
#
#                                                      Issue  \
# 4        Problem with a credit reporting company's inve...
# 126               Problems at the end of the loan or lease
# 156                            Struggling to pay your loan
# ...

# %%
data.loc[0:50, ['Company' , 'Sub-issue' , 'Consumer complaint narrative' ]];

# %% [markdown]
# > .loc lets you select the column that you want to see

# %% [markdown]
# # Summary and Grouping
# ### Quick info about types of data and count

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1627461 entries, 0 to 1627460
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   Date received                 1627461 non-null  object
#  1   Product                       1627461 non-null  object
#  2   Sub-product                   1392296 non-null  object
#  3   Issue                         1627460 non-null  object
#  4   Sub-issue                     1056443 non-null  object
#  5   Consumer complaint narrative  543037 non-null   object
#  6   Company public response       632125 non-null   object
#  7   Company                       1627461 non-null  object
#  8   State                         1599858 non-null  object
#  9   ZIP code                      1472102 non-null  object
#  10  Tags                          220305 non-null   object
#  11  Consumer consent provided?    987595 non-null   object
# ...

# %% [markdown]
# ## GroupBy

# %%
data.groupby('State').describe()
# Out:
#       Complaint ID                                                    \
#              count          mean           std       min         25%
# State
# AA            32.0  2.345109e+06  1.098335e+06  322779.0  1791700.25
# AE           569.0  2.090572e+06  1.015261e+06   10662.0  1309156.00
# AK          1699.0  2.149095e+06  1.083094e+06    2046.0  1211205.50
# AL         20435.0  2.452880e+06  1.016519e+06     706.0  1722127.00
# AP           405.0  2.133078e+06  9.880975e+05   26421.0  1258012.00
# ...            ...           ...           ...       ...         ...
# VT          1939.0  1.881156e+06  1.084706e+06    2108.0   935874.50
# WA         28828.0  2.082294e+06  1.046585e+06      56.0  1222483.25
# WI         15749.0  2.118700e+06  1.068005e+06     429.0  1217760.00
# WV          3589.0  2.087401e+06  1.051494e+06    1272.0  1211418.00
# WY          1459.0  2.174441e+06  1.098056e+06    3808.0  1227040.00
#
#
#              50%        75%        max
# State
# ...

# %%
data.groupby(['State', 'Company'])
data.groupby(['State', 'Company']).mean()
# Out:
#                                                 Complaint ID
# State Company
# AA    AES/PHEAA                                    1850461.0
#       BANCO POPULAR DE PUERTO RICO                 3206193.0
#       BANK OF NEW YORK MELLON CORPORATION, THE     1964081.0
#       CAPITAL ONE FINANCIAL CORPORATION             538200.0
#       CITIBANK, N.A.                                870620.0
# ...                                                      ...
# WY    WESTERN UNION COMPANY, THE                   1798562.4
#       Weltman, Weinberg & Reis Co., L.P.A.          767174.0
#       Williams & Fudge, Inc                         632904.0
#       YKS Acceptance, Inc.                         2309538.5
#       ZARVAD III S.A.                              1917595.0
#
# [49411 rows x 1 columns]
